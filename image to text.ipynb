# %%
pip install pytesseract
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pytesseract
from PIL import Image

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
image = Image.open('mom.jpeg')

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1402x920>

# %%
text = pytesseract.image_to_string(image)

# %%
print(text)
# Out:
# Date oom_ = = Date
# ane 21-05-28 — ra a
# 5 E@eGrlaf |
# Gis e le : = a
# “he See Res] Coe : ay fPIC ie gah
# Qe Diterint Shaft wal] 320) TA ] er fe x £m Ord, ae =
# 3, Review by Sifaiore 23/987 = 4A 2b > = EX
# Pretram #o ba given a a
# = ai ae Sree Combe? 27S _ wa i. i — —
# 5, Gloun [eG 2abirn~ 3p 30/6257 1 Chill
# 6+ Mates | 5a AS DEAE Ue Ne — -—
# beth cr
# fr 28%. fity 3p =n ae
# Sraem > Bete 19% flar> LY G9 = ; =
# = ae
#
# + date fick | Pawbiy
# 3222 Cnfbed | 6A flew barbbranseo//s~ T= : eis
# ¥ 4 > - 60/, “FU fain. 329/° EB t ae
# 5h 7 _$0/. I = a
#
# epee n ef adhe dof — au oer
# Ienbig op wtpamty Vvindex ef Roce ee Heo _
#
# q
#
# Digg
